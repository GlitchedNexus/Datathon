# %% [markdown]
# # 03 Advanced Models
# Objective: try improved features/models, compare to baselines, and document gains.
#
# TODO:
# - [ ] Engineer additional features and retry scaling/encoding
# - [ ] Train advanced models (e.g., boosted trees, xgboost)
# - [ ] Compare metrics vs baselines; update figures
# - [ ] Record decisions in reports/decisions.md
